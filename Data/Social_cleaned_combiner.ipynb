# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Data_Coin_price/crypto_social_data_hourly.csv')

# %%
df.head()
# Out:
#                     datetime  Twitter Volume BTC  Twitter Volume ETH  \
# 0  2021-01-01 00:00:00+00:00               122.0                19.0
# 1  2021-01-01 01:00:00+00:00               159.0                27.0
# 2  2021-01-01 02:00:00+00:00               149.0                19.0
# 3  2021-01-01 03:00:00+00:00               102.0                20.0
# 4  2021-01-01 04:00:00+00:00               130.0                26.0
#
#    Twitter Volume Doge  Reddit Volume BTC  Reddit Volume ETH  \
# 0                  2.0              112.0               21.0
# 1                  2.0              128.0               54.0
# 2                  3.0              145.0               52.0
# 3                  2.0              141.0               37.0
# 4                  3.0              119.0               21.0
#
#    Reddit Volume Doge  Twitter Positive Sentiment BTC  \
# 0                 9.0                       38.795690
# 1                19.0                       53.166277
# ...

# %%
df.describe()
# Out:
#        Twitter Volume BTC  Twitter Volume ETH  Twitter Volume Doge  \
# count         8784.000000         8784.000000          8784.000000
# mean           233.155624          116.960041            73.547587
# std            205.572052          171.313632           172.442425
# min              0.000000            0.000000             0.000000
# 25%            121.000000           33.000000            15.000000
# 50%            178.000000           53.000000            35.000000
# 75%            272.000000           99.000000            81.250000
# max           3567.000000         2424.000000          8324.000000
#
#        Reddit Volume BTC  Reddit Volume ETH  Reddit Volume Doge  \
# count          8784.0000        8784.000000         8784.000000
# mean            232.7352         153.197746          167.782901
# std             111.2272          89.377539          272.153092
# min               0.0000           0.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   datetime                         8784 non-null   object
#  1   Twitter Volume BTC               8784 non-null   float64
#  2   Twitter Volume ETH               8784 non-null   float64
#  3   Twitter Volume Doge              8784 non-null   float64
#  4   Reddit Volume BTC                8784 non-null   float64
#  5   Reddit Volume ETH                8784 non-null   float64
#  6   Reddit Volume Doge               8784 non-null   float64
#  7   Twitter Positive Sentiment BTC   8784 non-null   float64
#  8   Twitter Positive Sentiment ETH   8784 non-null   float64
#  9   Twitter Positive Sentiment Doge  8784 non-null   float64
#  10  Twitter Negative Sentiment BTC   8784 non-null   float64
# ...

# %%
#Remove timezone information in the datetime column
df['datetime'] = pd.to_datetime(df['datetime']).dt.tz_localize(None)
df= df[(df['datetime']>='2021-01-01') & (df['datetime']<'2022-01-01 00:00:00')]
df.head()
# Out:
#              datetime  Twitter Volume BTC  Twitter Volume ETH  \
# 0 2021-01-01 00:00:00               122.0                19.0
# 1 2021-01-01 01:00:00               159.0                27.0
# 2 2021-01-01 02:00:00               149.0                19.0
# 3 2021-01-01 03:00:00               102.0                20.0
# 4 2021-01-01 04:00:00               130.0                26.0
#
#    Twitter Volume Doge  Reddit Volume BTC  Reddit Volume ETH  \
# 0                  2.0              112.0               21.0
# 1                  2.0              128.0               54.0
# 2                  3.0              145.0               52.0
# 3                  2.0              141.0               37.0
# 4                  3.0              119.0               21.0
#
#    Reddit Volume Doge  Twitter Positive Sentiment BTC  \
# 0                 9.0                       38.795690
# 1                19.0                       53.166277
# 2                15.0                       54.901732
# ...

# %%
df.to_csv('Social_cleaned_hourly.csv')
